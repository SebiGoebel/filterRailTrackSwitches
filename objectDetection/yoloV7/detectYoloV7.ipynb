# %%
# !nvidia-smi
# Out:
# Tue Apr 23 16:00:20 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.65                 Driver Version: 551.86         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|

# %% [markdown]
# ### Preperation of directory

# %%
import os

os.chdir("/home/sebi/filterRailTrackSwitches/objectDetection/yoloV7/yolov7")  # change dir to get the right one
YOLOV7_DIR = os.getcwd()
print(YOLOV7_DIR)
# Out:
# /home/sebi/filterRailTrackSwitches/objectDetection/yoloV7/yolov7

# %% [markdown]
# ### Detection with pre-trained COCO model

# %%
# detect on a test image using pre-trained model
# !python {YOLOV7_DIR}/detect.py --weights {YOLOV7_DIR}/yolov7-tiny.pt --conf 0.25 --img-size 640 --source {YOLOV7_DIR}/inference/images/horses.jpg --device cpu
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='cpu', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='/home/sebi/filterRailTrackSwitches/objectDetection/yoloV7/yolov7/inference/images/horses.jpg', update=False, view_img=False, weights=['/home/sebi/filterRailTrackSwitches/objectDetection/yoloV7/yolov7/yolov7-tiny.pt'])
# YOLOR 🚀 v0.1-128-ga207844 torch 2.2.2+cu121 CPU
#
# ...
# Download error: [Errno 2] No such file or directory: '/home/sebi/filterrailtrackswitches/objectdetection/yolov7/yolov7/yolov7-tiny.pt.0bdcb934a23e4016a4702482c95cd9a8.partial'
# ERROR: Download failure: /home/sebi/filterrailtrackswitches/objectdetection/yolov7/yolov7/yolov7-tiny.pt missing, try downloading from https://github.com/WongKinYiu/yolov7/releases/
#
# Fusing layers...
# Model Summary: 200 layers, 6219709 parameters, 229245 gradients, 13.7 GFLOPS
# ...

# %% [markdown]
# ### showing detection of pre-traind COCO model

# %%
from IPython.display import Image

Image(filename=f"{YOLOV7_DIR}/runs/detect/exp/horses.jpg", width=600)
