# %%
# !nvidia-smi # geht auch noch nicht
# Out:
# Tue Apr  9 13:59:19 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.65                 Driver Version: 551.86         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|

# %% [markdown]
# ### Preperation of directory

# %%
import os

os.chdir("/home/sebi/filterRailTrackSwitches/objectDetection/yoloV9/")  # change dir to get the right one
YOLOV9_DIR = os.getcwd()
print(YOLOV9_DIR)
# Out:
# /home/sebi/filterRailTrackSwitches/objectDetection/yoloV9

# %% [markdown]
# ### Preperation of virtual environment

# %%
# !source {YOLOV9_DIR}/venv_yoloV9/bin/activate # funktioniert nicht richtig --> im terminal funktioniert es

# %% [markdown]
# ### Detection with pre-trained COCO model

# %%
# using pre-trained model for detection
# !python {YOLOV9_DIR}/yolov9/detect.py --weights {YOLOV9_DIR}/weights/yolov9-e.pt --conf 0.1 --source {YOLOV9_DIR}/data/dog.jpeg --device cpu
# Out:
# detect: weights=['/home/sebi/filterRailTrackSwitches/objectDetection/yoloV9/weights/yolov9-e.pt'], source=/home/sebi/filterRailTrackSwitches/objectDetection/yoloV9/data/dog.jpeg, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.8.10 torch-2.2.2+cu121 CPU
#
# Fusing layers...
# Model summary: 1119 layers, 69470144 parameters, 0 gradients, 244.0 GFLOPs
# image 1/1 /home/sebi/filterRailTrackSwitches/objectDetection/yoloV9/data/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 1 backpack, 1 handbag, 1149.3ms
# Speed: 1.2ms pre-process, 1149.3ms inference, 3.8ms NMS per image at shape (1, 3, 640, 640)
# ...

# %% [markdown]
# ### showing detection of pre-traind COCO model

# %%
from IPython.display import Image

Image(filename=f"{YOLOV9_DIR}/yolov9/runs/detect/exp/dog.jpeg", width=600)
